-- %%
SELECT * FROM "machine_learning_data_1";
-- Out:
-- (2415 row(s) affected)
-- Total execution time: 00:00:00.097
-- ...

-- %%
SELECT "Training Data" FROM "machine_learning_data_1";
-- Out:
-- (2415 row(s) affected)
-- Total execution time: 00:00:00.026
-- ...
